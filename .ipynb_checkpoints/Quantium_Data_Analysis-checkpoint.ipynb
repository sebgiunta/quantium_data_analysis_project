# %% [markdown]
# # Introduction
#
# TBC

# %%
#Import Modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Import Datasets

df_trans = pd.read_csv('datasets/QVI_transaction_data.csv')
df_cust = pd.read_csv('datasets/QVI_purchase_behaviour.csv')

# %% [markdown]
# #### Transaction Data Exploration

# %%
# Explore first 10 rows
display(df_trans.head(10))

# Check shape
display(df_trans.shape)

# Check for nulls and datatypes
display(df_trans.info())

# Understand unique values in categorical columns
display(df_trans.nunique())

# Describe the data
display(df_trans.describe(include='all').T)
# Out:
#    DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0   109          1            1000       1         5
# 1   317          1            1307     348        66
# 2   323          1            1343     383        61
# 3    48          2            2373     974        69
# 4    49          2            2426    1038       108
# 5   322          4            4074    2982        57
# 6   319          4            4149    3333        16
# 7   319          4            4196    3539        24
# 8    51          5            5026    4525        42
# 9    49          7            7150    6900        52
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
# 5  Old El Paso Salsa   Dip Tomato Mild 300g         1        5.1
# 6  Smiths Crinkle Chips Salt & Vinegar 330g         1        5.7
# 7     Grain Waves         Sweet Chilli 210g         1        3.6
# 8   Doritos Corn Chip Mexican Jalapeno 150g         1        3.9
# 9     Grain Waves Sour    Cream&Chives 210G         2        7.2
# (264836, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB
# None
# DATE                 364
# STORE_NBR            272
# LYLTY_CARD_NBR     72637
# TXN_ID            263127
# PROD_NBR             114
# PROD_NAME            114
# PROD_QTY               6
# TOT_SALES            112
# dtype: int64
#                  count unique                                     top  freq  \
# DATE            264836    NaN                                     NaN   NaN
# STORE_NBR       264836    NaN                                     NaN   NaN
# LYLTY_CARD_NBR  264836    NaN                                     NaN   NaN
# TXN_ID          264836    NaN                                     NaN   NaN
# PROD_NBR        264836    NaN                                     NaN   NaN
# PROD_NAME       264836    114  Kettle Mozzarella   Basil & Pesto 175g  3304
# PROD_QTY        264836    NaN                                     NaN   NaN
# TOT_SALES       264836    NaN                                     NaN   NaN
#
#                    mean       std   min      25%     50%     75%          max
# DATE            182.525   104.957     1       92     182     273          364
# STORE_NBR        135.08   76.7842     1       70     130     203          272
# LYLTY_CARD_NBR   135549     80580  1000    70021  130358  203094  2.37371e+06
# TXN_ID           135158     78133     1  67601.5  135138  202701  2.41584e+06
# PROD_NBR        56.5832   32.8266     1       28      56      85          114
# PROD_NAME           NaN       NaN   NaN      NaN     NaN     NaN          NaN
# PROD_QTY        1.90731  0.643654     1        2       2       2          200
# TOT_SALES        7.3042   3.08323   1.5      5.4     7.4     9.2          650

# %% [markdown]
# ---

# %% [markdown]
# - DATE column contains 364 unique values, ranging from 43282 to 43646. Will replace these with numbers 1 to 364 to represent date.
# - STORE_NBR, LYLTY_CARD_NBR, TXN_ID, PROD_NBR datatype is integer, we'll convert these to Objects

# %%
## Replace values in DATE

# List of unique values in Date + Sort
dates = list(set(df_trans.DATE.values))
dates.sort()

# List of unique values to replace current values of DATE
replacement = list(range(1,365))

# Create dictionary
date_map = dict(zip(dates, replacement))

# Map to dateframe
df_trans['DATE'] = df_trans['DATE'].map(date_map)

# %%
## Convert STORE_NBR, LYLTY_CARD_NBR, TXN_ID, PROD_NBR to objects
cols = ['STORE_NBR', 'LYLTY_CARD_NBR', 'TXN_ID', 'PROD_NBR']

for col in cols:
    df_trans[col] = df_trans[col].astype('object')

# %%
df_trans.describe(include='all').T
# Out:
#                  count  unique                                     top  freq  \
# DATE            264836     NaN                                     NaN   NaN
# STORE_NBR       264836     272                                     226  2022
# LYLTY_CARD_NBR  264836   72637                                  172032    18
# TXN_ID          264836  263127                                    1162     3
# PROD_NBR        264836     114                                     102  3304
# PROD_NAME       264836     114  Kettle Mozzarella   Basil & Pesto 175g  3304
# PROD_QTY        264836     NaN                                     NaN   NaN
# TOT_SALES       264836     NaN                                     NaN   NaN
#
#                    mean       std  min  25%  50%  75%  max
# DATE            182.525   104.957    1   92  182  273  364
# STORE_NBR           NaN       NaN  NaN  NaN  NaN  NaN  NaN
# LYLTY_CARD_NBR      NaN       NaN  NaN  NaN  NaN  NaN  NaN
# TXN_ID              NaN       NaN  NaN  NaN  NaN  NaN  NaN
# PROD_NBR            NaN       NaN  NaN  NaN  NaN  NaN  NaN
# PROD_NAME           NaN       NaN  NaN  NaN  NaN  NaN  NaN
# PROD_QTY        1.90731  0.643654    1    2    2    2  200
# TOT_SALES        7.3042   3.08323  1.5  5.4  7.4  9.2  650

# %%
sns.histplot(data=df_trans, x='STORE_NBR')
# Out:
# <AxesSubplot:xlabel='STORE_NBR', ylabel='Count'>

# %%
##TODO:

# Understand Date column
# Parse out Brand Names
# Parse out packet size

# %%
## Questions:

# Which stores have the highest total sales

# %% [markdown]
# #### Customer Data Exploration

# %%
# Explore first 10 rows
df_cust.head(10)
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream
# 5            1007   YOUNG SINGLES/COUPLES           Budget
# 6            1009            NEW FAMILIES          Premium
# 7            1010   YOUNG SINGLES/COUPLES       Mainstream
# 8            1011   OLDER SINGLES/COUPLES       Mainstream
# 9            1012          OLDER FAMILIES       Mainstream
